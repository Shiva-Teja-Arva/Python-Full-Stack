# %%
import requests
url = "https://codegnan.com"
response = requests.get(url)
print(response) # If status code is 200 then we can access the html source code in that website
print(response.status_code)
print(response.text[:500]) # slicing the html element in the source code
# Out:
# <Response [200]>
# 200
# <!doctype html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<link rel="profile" href="https://gmpg.org/xfn/11">
# 	<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
#
# 	<!-- This site is optimized with the Yoast SEO plugin v28.4 - https://yoast.com/product/yoast-seo-wordpress/ -->
# 	<title>Codegnan: Online &amp; classroom IT training institute (India)</title>
# 	<met

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser') # Soup object
print(soup.title) # provides the title of that website
print(soup.title.text) # provides the title in text
heading = soup.find_all("a")
for i in heading:
    print(i.text)
# Out:
# <title>Codegnan: Online &amp; classroom IT training institute (India)</title>
# Codegnan: Online & classroom IT training institute (India)
# Skip to content
#
#
# Programs
# Codegnan LaunchPad
# Codegnan Intensive Pro
# Career Restart
# Courses
# Data Science with Agentic AI Course
# Data Science with Agentic AI Course in Vijayawada
# Data Science with Agentic AI Course in Visakhapatnam
# Data Science with Agentic AI Course in Hyderabad
# MERN Stack
# MERN Stack Training Course in Vijayawada
# MERN Stack Training Course in Hyderabad
# Full Stack
# Full Stack Course in Vijayawada
# Full Stack Course in Hyderabad
# Full Stack Course in Visakhapatnam
# Python
# Python Training in Hyderabad
# Python Training in Vijayawada
# Python Full Stack
# Python Full Stack Course in Hyderabad
# Python Full Stack Course in Vijayawada
# Java
# Java Course in Hyderabad
# Java Course in Vijayawada
# Java Full Stack
# Java Full Stack Course in Hyderabad
# Java Full Stack Course in Vijayawada
# Data Science
# Data Science Course in Hyderabad
# Data Analytics Course in Vijayawada
# Data Science Course in Vijayawada
# Machine Learning
# Machine Learning Course in Hyderabad
# Machine Learning Course in Vijayawada
# Software Testing
# Software Testing Course in Hyderabad
# Software Testing Course in Vijayawada
# React JS Training in Vijayawada
# Data Structures Training in Vijayawada
# C Programming in Vijayawada
# Resources
# Blogs
# Academy
# Syllabus
# Java Syllabus
# Data Structures Syllabus
# Python Syllabus
# React JS Syllabus
# C Language Syllabus
# Data Science Syllabus
# Java Full Stack Syllabus
# Software Testing Syllabus
# Python Full Stack Syllabus
# Machine Learning Syllabus
# Project Ideas
# Java Projects
# Python Projects
# React JS Projects
# C Language Projects
# Data Science Projects
# Data Structure Projects
# Machine Learning Projects
# Software Testing Projects
# Career Paths
# Java Career Path
# Python Career Path
# Data Science Career Path
# Software Testing Career Path
# Machine Learning Career Path
# Career Guide
# Become a Python Full Stack Developer
# Become a Python Developer
# Become a Java Developer
# Become a Software Tester
# Become a Java Full Stack Developer
# Salary Report
# Java Developer in Bangalore
# Python Developer in Bangalore
# Machine Learning in Hyderabad
# Data Scientist in Hyderabad
# Software Tester in Hyderabad
# Python Developer in Hyderabad
# Java Developer in Hyderabad
# Interview Questions
# Java Interview Questions
# Python Interview Questions
# Data Science Interview Questions
# About
# Team
# FAQs
# Gallery
# Internships
# Job Accelerator Program
# Campuses
# Vijayawada (Main Branch)
# Visakhapatnam
# Hyderabad
# Contact Us
# Programs
# Codegnan LaunchPad
# Codegnan Intensive Pro
# Career Restart
# Courses
# Data Science with Agentic AI Course
# Data Science with Agentic AI Course in Vijayawada
# Data Science with Agentic AI Course in Visakhapatnam
# Data Science with Agentic AI Course in Hyderabad
# MERN Stack
# MERN Stack Training Course in Vijayawada
# MERN Stack Training Course in Hyderabad
# Full Stack
# Full Stack Course in Vijayawada
# Full Stack Course in Hyderabad
# Full Stack Course in Visakhapatnam
# Python
# Python Training in Hyderabad
# Python Training in Vijayawada
# Python Full Stack
# Python Full Stack Course in Hyderabad
# Python Full Stack Course in Vijayawada
# Java
# Java Course in Hyderabad
# Java Course in Vijayawada
# Java Full Stack
# Java Full Stack Course in Hyderabad
# Java Full Stack Course in Vijayawada
# Data Science
# Data Science Course in Hyderabad
# Data Analytics Course in Vijayawada
# Data Science Course in Vijayawada
# Machine Learning
# Machine Learning Course in Hyderabad
# Machine Learning Course in Vijayawada
# Software Testing
# Software Testing Course in Hyderabad
# Software Testing Course in Vijayawada
# React JS Training in Vijayawada
# Data Structures Training in Vijayawada
# C Programming in Vijayawada
# Resources
# Blogs
# Academy
# Syllabus
# Java Syllabus
# Data Structures Syllabus
# Python Syllabus
# React JS Syllabus
# C Language Syllabus
# Data Science Syllabus
# Java Full Stack Syllabus
# Software Testing Syllabus
# Python Full Stack Syllabus
# Machine Learning Syllabus
# Project Ideas
# Java Projects
# Python Projects
# React JS Projects
# C Language Projects
# Data Science Projects
# Data Structure Projects
# Machine Learning Projects
# Software Testing Projects
# Career Paths
# Java Career Path
# Python Career Path
# Data Science Career Path
# Software Testing Career Path
# Machine Learning Career Path
# Career Guide
# Become a Python Full Stack Developer
# Become a Python Developer
# Become a Java Developer
# Become a Software Tester
# Become a Java Full Stack Developer
# Salary Report
# Java Developer in Bangalore
# Python Developer in Bangalore
# Machine Learning in Hyderabad
# Data Scientist in Hyderabad
# Software Tester in Hyderabad
# Python Developer in Hyderabad
# Java Developer in Hyderabad
# Interview Questions
# Java Interview Questions
# Python Interview Questions
# Data Science Interview Questions
# About
# Team
# FAQs
# Gallery
# Internships
# Job Accelerator Program
# Campuses
# Vijayawada (Main Branch)
# Visakhapatnam
# Hyderabad
# Contact Us
#
#
# Placements
#
#
#
#
# Login
#
#
#
#
#
# New course ‘JAP’ know more
#
#
#
# Know More
#
#
#
#
# Intensive Pro
#
#
#
#
# Explore Program
#
#
#
#
#
#
# Request a Callback
#
#
# Know more
#
#
#
#
# Request a Callback
#
#
# Know more
#
#
#
#
# Request a Callback
#
#
# Know more
#
#
#
#
# Request Call
#
#
#
#
#
#
# Request a Callback
#
#
#
#
# Want to become a Java Full Stack Developer?
#
# Google Logo
#
#
# Amazon
#
#
# Meta Logo
#
#
# Microsoft Logo
#
#
#
#
#
# Request a Callback
#
#
#
#
# Want to become a Python Full Stack Developer?
#
# Amazon
#
#
# Cloud Icon
#
#
# Meta Logo
#
#
# TCS
#
#
#
#
#
# Request a Callback
#
#
#
#
# Want to become a Data Analyst?
#
# Wipro
#
#
# Infosys
#
#
# Zoho
#
#
# Microsoft Logo
#
#
#
#
#
# Request a Callback
#
#
#
#
# Want to become a Data Scientist with AI?
#
# Wipro
#
#
# Infosys
#
#
# Zoho
#
#
# Microsoft Logo
#
#
#
#
#
# Request a Callback
#
#
#
#
#
#
# Request Call
#
#
#
#
# 3.4 LPA
#
#
#
#
# 3.4 LPA
#
#
#
#
# 3.2 LPA
#
#
#
#
# 3 LPA
#
#
#
#
# 3 LPA
#
#
#
#
# 4 LPA
#
#
#
#
#
#
# Request Call
#
#
#
#
#  Play
#
#
#
#
#
#  Play
#
#
#
#
#
#  Play
#
#
#
#
#
#  Play
#
#
#
#
#
#  Play
#
#
#
#
#
#  Play
#
#
#
#
#
# Know More
#
#
#
#
# Python
# Can You Learn Python Without a Programming Background?
#
#
#
#
# Know More
#
#
#
#
# DevOps
# DevOps Engineer Salary in India (2026): A Complete Guide by Experience, City, and Skills
#
#
#
#
# Know More
#
#
#
#
# Agentic AI
# How Project-Based Gen AI Learning Make Beginners Job-Ready
#
#
#
#
# Know More
#
#
#
#
# Full Stack
# Full Stack Developer Course in Hyderabad: Become Job-Ready in 120 Days with Codegnan
#
#
#
#
# Know More
#
#
#
#
# Academy
# Tech Jobs in Andhra Pradesh: How the Growing IT Ecosystem Is Creating Opportunities
#
#
#
#
# Know More
#
#
#
#
# C language
# Factorial Program in C: Code, Logic & Examples
#
#
#
#
# Know More
#
#
#
#
#
#
# View All Blogs
#
#
#
#
#
#
# Request a Callback
#
#
#
#
#
# Hackathon
#
#
#
#
# Events
#
#
#
#
# Workshops
#
#
#
#
# Communities
#
#
#
#
# Blogs
#
#
# About Us
#
#
# Internships
#
#
# Placements
#
#
# Job Acceleration Program
#
#
# Java Full Stack
#
#
# Python Full Stack
#
#
# Data Analytics
#
#
# Data Structures
#
#
# C Programming
#
#
# Software Testing
#
#
# Data Science
#
#
#
#
# 							Vijayawada
#
#
#
#
# 6301341478
#
#
#
#
#
# 							Hyderabad: JNTUH
#
#
#
#
# 8977544092
#
#
#
#
#
# 							Visakhapatnam
#
#
#
#
# 9966992587
#
#
#
#
# Our Branches
#
#
#
# Python Training in Vijayawada
#
#
# Python Full Stack Course Vijayawada
#
#
# Full Stack Java Course in Vijayawada
#
#
# Data Science Training in Vijayawada
#
#
# Machine Learning in Vijayawada
#
#
# React JS Training in Vijayawada
#
#
# Data Structures Course in Vijayawada
#
#
# C Programming Course in Vijayawada
#
#
# Software Testing Training Course in Vijayawada
#
#
# Full Stack Developer Course in Vijayawada
#
#
# Python Training in Hyderabad
#
#
# Python Full Stack Training in Hyderabad
#
#
# Core Java Training in Hyderabad
#
#
# Java Full Stack Course in Hyderabad
#
#
# Data Science Training in Hyderabad
#
#
# Machine Learning Course in Hyderabad
#
#
# Software Testing Training in Hyderabad
#
#
# Full Stack Developer Course in Hyderabad
#
#
# Python Course in Visakhapatnam
#
#
# Python Full Stack Developer Course in Visakhapatnam
#
#
# Core Java Training in Visakhapatnam
#
#
# Software Testing Training Course in Visakhapatnam
#
#
# Full Stack Developer Course in Visakhapatnam
#
#
# Linkedin
#
#
# Youtube
#
#
# Facebook
#
#
# X-twitter
#
#
# Instagram
#
#
# Whatsapp
#
#
# Telegram
#
#
# Chat with us
#
#
# Vijayawada
# Hyderabad
# Visakhapatnam
# Vijayawada
# Visakhapatnam
# Hyderabad
# Vijayawada
# Visakhapatnam
# Hyderabad
# Vijayawada
# Visakhapatnam
# Hyderabad
# Vijayawada
# Hyderabad
# Visakhapatnam
